# %%
# Importing Library

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fh = pd.read_csv(r"C:\Users\kisho\Python\Python_Case_Studies\customer_churn_data.csv")

# %%
fh
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
fh.describe()
# Out:
#          year    customer_id         age  no_of_days_subscribed  \
# count  2000.0    2000.000000  2000.00000            2000.000000
# mean   2015.0  554887.157500    38.69050              99.750000
# std       0.0  261033.690318    10.20641              39.755386
# min    2015.0  100198.000000    18.00000               1.000000
# 25%    2015.0  328634.750000    32.00000              73.000000
# 50%    2015.0  567957.500000    37.00000              99.000000
# 75%    2015.0  773280.250000    44.00000             127.000000
# max    2015.0  999961.000000    82.00000             243.000000
#
#        weekly_mins_watched  minimum_daily_mins  maximum_daily_mins  \
# count          2000.000000         2000.000000         2000.000000
# mean            270.178425           10.198700           30.620780
# std              80.551627            2.785519            9.129165
# min               0.000000            0.000000            0.000000
# ...

# %%
fh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    2000 non-null   int64
#  1   customer_id             2000 non-null   int64
#  2   phone_no                2000 non-null   object
#  3   gender                  1976 non-null   object
#  4   age                     2000 non-null   int64
#  5   no_of_days_subscribed   2000 non-null   int64
#  6   multi_screen            2000 non-null   object
#  7   mail_subscribed         2000 non-null   object
#  8   weekly_mins_watched     2000 non-null   float64
#  9   minimum_daily_mins      2000 non-null   float64
#  10  maximum_daily_mins      2000 non-null   float64
#  11  weekly_max_night_mins   2000 non-null   int64
#  12  videos_watched          2000 non-null   int64
#  13  maximum_days_inactive   1972 non-null   float64
# ...

# %%
fh.value_counts("gender")
# Out:
# gender
# Male      1053
# Female     923
# Name: count, dtype: int64

# %%
fh.columns
# Out:
# Index(['year', 'customer_id', 'phone_no', 'gender', 'age',
#        'no_of_days_subscribed', 'multi_screen', 'mail_subscribed',
#        'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
#        'weekly_max_night_mins', 'videos_watched', 'maximum_days_inactive',
#        'customer_support_calls', 'churn'],
#       dtype='object')

# %%
len(fh.columns)
# Out:
# 16

# %%
fh.shape
# Out:
# (2000, 16)

# %%
fh.head()
# Out:
#    year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0  2015       100198  409-8743  Female   36                     62
# 1  2015       100643  340-5930  Female   39                    149
# 2  2015       100756  372-3750  Female   65                    126
# 3  2015       101595  331-4902  Female   24                    131
# 4  2015       101653  351-8398  Female   40                    191
#
#   multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 0           no              no               148.35                12.2
# 1           no              no               294.45                 7.7
# 2           no              no                87.30                11.9
# 3           no             yes               321.30                 9.5
# 4           no              no               243.00                10.9
#
#    maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 0               16.81                     82               1
# ...

# %%
fh.head(15)
# Out:
#     year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0   2015       100198  409-8743  Female   36                     62
# 1   2015       100643  340-5930  Female   39                    149
# 2   2015       100756  372-3750  Female   65                    126
# 3   2015       101595  331-4902  Female   24                    131
# 4   2015       101653  351-8398  Female   40                    191
# 5   2015       101953  329-6603     NaN   31                     65
# 6   2015       103051  416-1845     NaN   54                     59
# 7   2015       103225  348-7193  Female   40                     50
# 8   2015       103408  413-4039    Male   61                    205
# 9   2015       103676  338-5207    Male   31                     63
# 10  2015       103697  411-9554    Male   34                    114
# 11  2015       103738  392-5296    Male   34                    107
# 12  2015       104025  380-6722  Female   30                     84
# ...

# %%
fh.tail(12)
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 1988  2015       992113  333-2906  Female   61                    133
# 1989  2015       992456  392-3813    Male   25                    144
# 1990  2015       993714  364-1969    Male   32                     61
# 1991  2015       993815  387-5891    Male   49                     50
# 1992  2015       994954  329-3222  Female   42                    119
# 1993  2015       996129  401-3170    Male   36                    127
# 1994  2015       996524  351-9604  Female   60                    141
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
# ...

# %%
fh.tail()
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 1995           no             yes               182.25                11.3
# 1996           no              no               273.45                 9.3
# 1997           no              no               128.85                15.6
# 1998           no              no               178.05                10.4
# 1999           no              no               326.70                10.3
#
#       maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# ...

# %%
fh.sample()
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 1153  2015       633760  391-8554  Female   25                    146
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 1153           no             yes               303.75                 7.8
#
#       maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 1153               34.43                     77               2
#
#       maximum_days_inactive  customer_support_calls  churn
# 1153                    3.0                       1    0.0

# %%
fh.sample(3)
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 1891  2015       954243  418-9502  Female   36                    179
# 121   2015       148676  370-7546    Male   37                     87
# 1688  2015       861280  330-9833  Female   35                     76
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 1891           no              no               256.05                13.3
# 121            no              no               235.20                 7.6
# 1688           no              no               297.45                12.5
#
#       maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 1891               29.02                    107               4
# 121                26.66                     77               6
# 1688               33.71                     96               3
#
#       maximum_days_inactive  customer_support_calls  churn
# 1891                    4.0                       1    0.0
# ...

# %%
fh.isnull().sum()
# Out:
# year                       0
# customer_id                0
# phone_no                   0
# gender                    24
# age                        0
# no_of_days_subscribed      0
# multi_screen               0
# mail_subscribed            0
# weekly_mins_watched        0
# minimum_daily_mins         0
# maximum_daily_mins         0
# weekly_max_night_mins      0
# videos_watched             0
# maximum_days_inactive     28
# customer_support_calls     0
# churn                     35
# dtype: int64

# %%
fh.describe(include = object)
# Out:
#         phone_no gender multi_screen mail_subscribed
# count       2000   1976         2000            2000
# unique      2000      2            2               2
# top     409-8743   Male           no              no
# freq           1   1053         1802            1430

# %%
fh.drop(["year"], axis = 1 )
# Out:
#       customer_id  phone_no  gender  age  no_of_days_subscribed multi_screen  \
# 0          100198  409-8743  Female   36                     62           no
# 1          100643  340-5930  Female   39                    149           no
# 2          100756  372-3750  Female   65                    126           no
# 3          101595  331-4902  Female   24                    131           no
# 4          101653  351-8398  Female   40                    191           no
# ...           ...       ...     ...  ...                    ...          ...
# 1995       997132  385-7387  Female   54                     75           no
# 1996       998086  383-9255    Male   45                    127           no
# 1997       998474  353-2080     NaN   53                     94           no
# 1998       998934  359-7788    Male   40                     94           no
# 1999       999961  414-1496    Male   37                     73           no
#
# ...

# %%
fh1=fh.drop(["year"], axis = 1 )

# %%
fh1
# Out:
#       customer_id  phone_no  gender  age  no_of_days_subscribed multi_screen  \
# 0          100198  409-8743  Female   36                     62           no
# 1          100643  340-5930  Female   39                    149           no
# 2          100756  372-3750  Female   65                    126           no
# 3          101595  331-4902  Female   24                    131           no
# 4          101653  351-8398  Female   40                    191           no
# ...           ...       ...     ...  ...                    ...          ...
# 1995       997132  385-7387  Female   54                     75           no
# 1996       998086  383-9255    Male   45                    127           no
# 1997       998474  353-2080     NaN   53                     94           no
# 1998       998934  359-7788    Male   40                     94           no
# 1999       999961  414-1496    Male   37                     73           no
#
# ...

# %%
fh1['churn']
# Out:
# 0       0.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       0.0
#        ...
# 1995    NaN
# 1996    0.0
# 1997    0.0
# 1998    0.0
# 1999    1.0
# Name: churn, Length: 2000, dtype: float64

# %%
fh1['churn'].nunique()
# Out:
# 2

# %%
fh1['churn'].value_counts()
# Out:
# churn
# 0.0    1703
# 1.0     262
# Name: count, dtype: int64

# %%
fh1['churn'].value_counts(dropna = False)
# Out:
# churn
# 0.0    1703
# 1.0     262
# NaN      35
# Name: count, dtype: int64

# %%
fh1['churn'].value_counts(dropna = False,normalize = True)
# Out:
# churn
# 0.0    0.8515
# 1.0    0.1310
# NaN    0.0175
# Name: proportion, dtype: float64

# %%
fh1['churn'].value_counts(dropna = False,normalize = True) *100
# Out:
# churn
# 0.0    85.15
# 1.0    13.10
# NaN     1.75
# Name: proportion, dtype: float64

# %%
fh1['churn'].astype('object')
# Out:
# 0       0.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       0.0
#        ...
# 1995    NaN
# 1996    0.0
# 1997    0.0
# 1998    0.0
# 1999    1.0
# Name: churn, Length: 2000, dtype: object

# %%
fh1['churn'].map({ 0.0 : 'yes',1.0 : 'no'})
# Out:
# 0       yes
# 1       yes
# 2        no
# 3       yes
# 4       yes
#        ...
# 1995    NaN
# 1996    yes
# 1997    yes
# 1998    yes
# 1999     no
# Name: churn, Length: 2000, dtype: object

# %%
fh1['churn'] = fh1['churn'].map({ 0.0 : 'yes',1.0 : 'no'})

# %%
fh1
# Out:
#       customer_id  phone_no  gender  age  no_of_days_subscribed multi_screen  \
# 0          100198  409-8743  Female   36                     62           no
# 1          100643  340-5930  Female   39                    149           no
# 2          100756  372-3750  Female   65                    126           no
# 3          101595  331-4902  Female   24                    131           no
# 4          101653  351-8398  Female   40                    191           no
# ...           ...       ...     ...  ...                    ...          ...
# 1995       997132  385-7387  Female   54                     75           no
# 1996       998086  383-9255    Male   45                    127           no
# 1997       998474  353-2080     NaN   53                     94           no
# 1998       998934  359-7788    Male   40                     94           no
# 1999       999961  414-1496    Male   37                     73           no
#
# ...

# %%
fh['churn'].value_counts()
# Out:
# churn
# 0.0    1703
# 1.0     262
# Name: count, dtype: int64

# %%
fh['churn'].value_counts(dropna = False)
# Out:
# churn
# 0.0    1703
# 1.0     262
# NaN      35
# Name: count, dtype: int64

# %%
fh['churn'].value_counts(dropna = False , normalize = True)
# Out:
# churn
# 0.0    0.8515
# 1.0    0.1310
# NaN    0.0175
# Name: proportion, dtype: float64

# %%
fh['churn'].value_counts(dropna = False , normalize = True)*100
# Out:
# churn
# 0.0    85.15
# 1.0    13.10
# NaN     1.75
# Name: proportion, dtype: float64

# %%
fh['gender'].value_counts(dropna = False, normalize = True)*100
# Out:
# gender
# Male      52.65
# Female    46.15
# NaN        1.20
# Name: proportion, dtype: float64

# %%
fh['multi_screen'].value_counts(dropna=False,normalize = True)*100
# Out:
# multi_screen
# no     90.1
# yes     9.9
# Name: proportion, dtype: float64

# %%
fh['mail_subscribed'].value_counts(dropna=False,normalize = True)*100
# Out:
# mail_subscribed
# no     71.5
# yes    28.5
# Name: proportion, dtype: float64

# %%
sns.countplot(data = fh1 , x = 'gender')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(x = 'gender' , data = fh1 , color = 'blue'  , hue = 'gender')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(x = 'gender' , data = fh1, hue = 'churn')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
#Annotate


ax = sns.countplot(x = 'gender' , data = fh1)

# %%
ax
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
print(ax)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
ax.patches
# Out:
# <Axes.ArtistList of 2 patches>

# %%
for patch in ax.patches:
    print(patch)
# Out:
# Rectangle(xy=(-0.4, 0), width=0.8, height=923, angle=0)
# Rectangle(xy=(0.6, 0), width=0.8, height=1053, angle=0)

# %%
for patch in ax.patches:
    h = patch.get_height()
    print(h)
# Out:
# 923.0
# 1053.0

# %%
ax = sns.countplot(data = fh1 , x = 'gender' ,palette = ['blue','red'])

for patch in ax.patches:
    h = patch.get_height()
    w = patch.get_x()
    print(h)
    print(w)
    ax.annotate(h,xy = ((w+ 0.3),(h/2)))
# Out:
# 923.0
# -0.4
# 1053.0
# 0.6

# %%
fh1['gender'].value_counts(dropna = False)
# Out:
# gender
# Male      1053
# Female     923
# NaN         24
# Name: count, dtype: int64

# %%
plt.pie(fh1['gender'].value_counts(dropna = False),labels = fh1['gender'].value_counts(dropna = False).index , autopct = '%.2f%%')
plt.show()

# %%
help(plt.pie)
# Out:
# Help on function pie in module matplotlib.pyplot:
#
# pie(x: 'ArrayLike', explode: 'ArrayLike | None' = None, labels: 'Sequence[str] | None' = None, colors: 'ColorType | Sequence[ColorType] | None' = None, autopct: 'str | Callable[[float], str] | None' = None, pctdistance: 'float' = 0.6, shadow: 'bool' = False, labeldistance: 'float | None' = 1.1, startangle: 'float' = 0, radius: 'float' = 1, counterclock: 'bool' = True, wedgeprops: 'dict[str, Any] | None' = None, textprops: 'dict[str, Any] | None' = None, center: 'tuple[float, float]' = (0, 0), frame: 'bool' = False, rotatelabels: 'bool' = False, *, normalize: 'bool' = True, hatch: 'str | Sequence[str] | None' = None, data=None) -> 'tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]'
#     Plot a pie chart.
#
#     Make a pie chart of array *x*.  The fractional area of each wedge is
#     given by ``x/sum(x)``.
#
#     The wedges are plotted counterclockwise, by default starting from the
#     x-axis.
#
# ...

# %%
fh1['multi_screen'].value_counts(dropna = True)
# Out:
# multi_screen
# no     1802
# yes     198
# Name: count, dtype: int64

# %%
plt.pie(fh1['multi_screen'].value_counts(dropna = True),labels = fh1['multi_screen'].value_counts(dropna = True).index,autopct = '%.2f%%')
plt.show()

# %%
plt.pie(fh1['mail_subscribed'].value_counts(dropna = True),labels =fh1['mail_subscribed'].value_counts(dropna = True).index,autopct = '%.2f%%' )
plt.show()

# %%
plt.pie(fh1['churn'].value_counts(dropna = True),labels =fh1['churn'].value_counts(dropna = True).index,autopct = '%.2f%%' )
plt.show()

# %%
fh1
# Out:
#       customer_id  phone_no  gender  age  no_of_days_subscribed multi_screen  \
# 0          100198  409-8743  Female   36                     62           no
# 1          100643  340-5930  Female   39                    149           no
# 2          100756  372-3750  Female   65                    126           no
# 3          101595  331-4902  Female   24                    131           no
# 4          101653  351-8398  Female   40                    191           no
# ...           ...       ...     ...  ...                    ...          ...
# 1995       997132  385-7387  Female   54                     75           no
# 1996       998086  383-9255    Male   45                    127           no
# 1997       998474  353-2080     NaN   53                     94           no
# 1998       998934  359-7788    Male   40                     94           no
# 1999       999961  414-1496    Male   37                     73           no
#
# ...

# %%
fh1['no_of_days_subscribed']
# Out:
# 0        62
# 1       149
# 2       126
# 3       131
# 4       191
#        ...
# 1995     75
# 1996    127
# 1997     94
# 1998     94
# 1999     73
# Name: no_of_days_subscribed, Length: 2000, dtype: int64

# %%
sns.displot(fh1['no_of_days_subscribed'])
# Out:
# C:\Users\kisho\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(fh1['no_of_days_subscribed'],kde=True)
# Out:
# C:\Users\kisho\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
fh1
# Out:
#       customer_id  phone_no  gender  age  no_of_days_subscribed multi_screen  \
# 0          100198  409-8743  Female   36                     62           no
# 1          100643  340-5930  Female   39                    149           no
# 2          100756  372-3750  Female   65                    126           no
# 3          101595  331-4902  Female   24                    131           no
# 4          101653  351-8398  Female   40                    191           no
# ...           ...       ...     ...  ...                    ...          ...
# 1995       997132  385-7387  Female   54                     75           no
# 1996       998086  383-9255    Male   45                    127           no
# 1997       998474  353-2080     NaN   53                     94           no
# 1998       998934  359-7788    Male   40                     94           no
# 1999       999961  414-1496    Male   37                     73           no
#
# ...

# %%
fh1.isnull().sum()
# Out:
# customer_id                0
# phone_no                   0
# gender                    24
# age                        0
# no_of_days_subscribed      0
# multi_screen               0
# mail_subscribed            0
# weekly_mins_watched        0
# minimum_daily_mins         0
# maximum_daily_mins         0
# weekly_max_night_mins      0
# videos_watched             0
# maximum_days_inactive     28
# customer_support_calls     0
# churn                     35
# dtype: int64

# %%
fh1['gender'].value_counts()
# Out:
# gender
# Male      1053
# Female     923
# Name: count, dtype: int64

# %%
fh1['gender'].mode()
# Out:
# 0    Male
# Name: gender, dtype: object

# %%
fh1['gender'].mode().iloc[0]
# Out:
# 'Male'
